# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
print(df_train.shape)
df_test.shape
# Out:
# (1460, 81)
# (1459, 80)

# %%
df_train.head(n=5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head(n=5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_combined = df_train.append(df_test,sort=False)
df_combined.iloc[:1460,] # Train Set
df_combined.iloc[1460:,] # Test Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Helper Functions

# %%
def indices_of_outliers(df, column_name, stdev_threshold):
    mask_of_outliers = np.abs(df[column_name] - df[column_name].mean()) >= (stdev_threshold*df[column_name].std())
    set_of_indices_of_outliers = df.index[mask_of_outliers].tolist()
    return set_of_indices_of_outliers

# example
indices_of_outliers(df_combined, "LotFrontage", 4)
# Out:
# [197, 231, 934, 1107, 1127, 1298, 804, 1139]

# %%
def remove_rows_with_outliers(df, list_of_column_names, stdev_threshold):
    outlier_index = []
    for col in list_of_column_names:
        set_of_indices_of_outliers = indices_of_outliers(df, col, stdev_threshold)
        outlier_index.extend(set_of_indices_of_outliers)
    outlier_index = list(set(outlier_index))
    df_without_outliers = df.drop(df.index[outlier_index])
    return df_without_outliers

# example
list_of_column_names = ["LotFrontage", "OverallQual", "LotArea"]
remove_rows_with_outliers(df_combined, list_of_column_names, stdev_threshold = 4)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Sanity Check

# %%
# df.loc[df["YearRemodAdd"] > df["YrSold"], ["YearRemodAdd","YrSold","YearBuilt"]]

# # Age of house = YearSold - 0.6*YearRemod - 0.4*YrBuilt
# # This would produce a negative age
# # Proposed solution: add 1.0 year to every single house's age...then this observation would become positive

# %%
# MasVnrArea = 0, but the MasVnrType is "Stone" or "BrkFace"
# df.loc[df["MasVnrArea"]==0]["MasVnrType"].value_counts()

# %% [markdown]
# # NA Imputation

# %%
# check NA in original df
df_combined.isnull().sum()[df_combined.isnull().sum()>0]
# Out:
# MSZoning           4
# LotFrontage      486
# Alley           2721
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# SaleType           1
# SalePrice       1459
# dtype: int64

# %%
series_names = ['BsmtExposure','BsmtQual','FireplaceQu','GarageQual','GarageType','GarageYrBlt','GarageFinish','GarageCond','PoolQC','Fence','MiscFeature','Alley','BsmtCond','BsmtFinType1','BsmtFinType2']
for series_name in series_names:
    df_combined.loc[df_combined[series_name].isnull(),series_name] = 'None'
    print(df_combined[series_name].value_counts(sort = True))
    print('*'*20)
# Out:
# No      1904
# Av       418
# Gd       276
# Mn       239
# None      82
# Name: BsmtExposure, dtype: int64
# ********************
# TA      1283
# Gd      1209
# Ex       258
# Fa        88
# None      81
# Name: BsmtQual, dtype: int64
# ********************
# None    1420
# Gd       744
# TA       592
# Fa        74
# Po        46
# Ex        43
# Name: FireplaceQu, dtype: int64
# ********************
# TA      2604
# None     159
# Fa       124
# Gd        24
# Po         5
# Ex         3
# Name: GarageQual, dtype: int64
# ********************
# Attchd     1723
# Detchd      779
# BuiltIn     186
# None        157
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64
# ********************
# None      159
# 2005.0    142
# 2007.0    115
# 2006.0    115
# 2004.0     99
#          ...
# 1906.0      1
# 1896.0      1
# 1895.0      1
# 2207.0      1
# 1933.0      1
# Name: GarageYrBlt, Length: 104, dtype: int64
# ********************
# Unf     1230
# ...

# %%
df_combined.isnull().sum()[df_combined.isnull().sum()>0]
# Out:
# MSZoning           4
# LotFrontage      486
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# GarageCars         1
# GarageArea         1
# SaleType           1
# SalePrice       1459
# dtype: int64

# %%
df_combined['LotFrontage'] = df_combined.groupby(['Neighborhood'])['LotFrontage'].transform(lambda x: x.fillna(x.median()))
df_combined['Electrical'] = df_combined['Electrical'].fillna('SBrkr')
df_combined['MasVnrType'] = df_combined.groupby(['Neighborhood'])['MasVnrType'].transform(lambda x: x.fillna(x.mode()[0]))
# Where there is no MasVnrType, assign the missing values of area to be zero
mask_1 = (df_combined["MasVnrType"] == "None") & (df_combined["MasVnrArea"].isna())
df_combined.loc[mask_1, "MasVnrArea"]  = 0.0
# There is 1 house with a "stone" type MasVnrType, with no area, so we impute using median area for stone types
df_combined['MasVnrArea'] = df_combined.groupby(['MasVnrType'])['MasVnrArea'].transform(lambda x: x.fillna(x.median()))
# There is one house in test set that containing missing value in GarageArea, seems like it does not have a Garage
df_combined['GarageArea']= df_combined['GarageArea'].fillna(0)
df_combined['GarageCars']= df_combined['GarageCars'].fillna(0)
# Only one house has missing value in BsmtSF due to no basement, should fill NA with 0
df_combined['TotalBsmtSF'] = df_combined['TotalBsmtSF'].fillna(0)
df_combined['BsmtFinSF1'] = df_combined['BsmtFinSF1'].fillna(0)
df_combined['BsmtFinSF2'] = df_combined['BsmtFinSF2'].fillna(0)
df_combined['BsmtUnfSF'] = df_combined['BsmtUnfSF'].fillna(0)
# There are 2 houses that have missing values in basement bathroom due to no basement 
df_combined['BsmtFullBath'] = df_combined['BsmtFullBath'].fillna(0)
df_combined['BsmtHalfBath'] = df_combined['BsmtHalfBath'].fillna(0)
df_combined['Exterior1st'] = df_combined.groupby(['RoofMatl'])['Exterior1st'].transform(lambda x: x.fillna(x.mode()[0])) 
df_combined['Exterior2nd'] = df_combined.groupby(['RoofMatl'])['Exterior2nd'].transform(lambda x: x.fillna(x.mode()[0])) 
df_combined['KitchenQual'] = df_combined.groupby(['OverallCond'])['KitchenQual'].transform(lambda x: x.fillna(x.mode()[0])) # group by Overall Condition
# 2 houses have missing values in Functional. Both are in poor quality condition and sold as abnormal type. Should not consider it as Functional_typ
df_combined['Functional'] = df_combined['Functional'].fillna('Mod')
# 4 houses having missing values in MSZoning
df_combined['MSZoning'] = df_combined.groupby(['Neighborhood'])['MSZoning'].transform(lambda x:x.fillna(x.mode()[0]))
df_combined['Utilities'] = df_combined['Utilities'].fillna('AllPub')
df_combined['SaleType'] = df_combined.groupby(['SaleCondition'])['SaleType'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df_combined.isnull().sum()[df_combined.isnull().sum()>0]
# Out:
# SalePrice    1459
# dtype: int64

# %% [markdown]
# # Create Custom Features

# %%
# Create Custom Feature: Adjusted Total Basement Area
df_combined['AdjTotalBsmtSF'] = df_combined['BsmtFinSF1']+df_combined['BsmtFinSF2']+0.9*df_combined['BsmtUnfSF']
# Create Custom Feature: Adjusted Total Bathroom 
df_combined['AdjTotalBath'] = df_combined['FullBath']+df_combined['BsmtFullBath']+0.6*(df_combined['HalfBath']+df_combined['BsmtHalfBath'])
# Create Custom Feature: HouseAge
df_combined['HouseAge'] = df_combined['YrSold']-(0.6*df_combined['YearRemodAdd']+0.4*df_combined['YearBuilt'])
# Custom Feature: AdjOutdoorSF
df_combined['AdjOutdoorSF'] = df_combined['3SsnPorch']+df_combined['EnclosedPorch']+df_combined['OpenPorchSF']+df_combined['ScreenPorch']+df_combined['WoodDeckSF']

df_combined.shape
df_combined.to_csv("combined.csv",index=False)

# %% [markdown]
# ### Converting Categorical Features

# %%
df_combined.GarageYrBlt.dtype
# Out:
# dtype('O')

# %%
df_combined.select_dtypes(include=[object])
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1454       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave  None      Reg         Lvl    AllPub    Inside       Mod
#
# ...

# %%
df_categorical = df_combined.select_dtypes(include=[object]).drop('GarageYrBlt',axis =1) # 43 categorical columns
categorical_columns = df_categorical.columns.to_list()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_categorical_le = df_categorical.apply(le.fit_transform)
df_categorical_le.head(5)
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      1         3            3          0          4
# 1         3       1      1         3            3          0          2
# 2         3       1      1         0            3          0          4
# 3         3       1      1         0            3          0          0
# 4         3       1      1         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  ...  GarageType  GarageFinish  \
# 0          0             5           2  ...           1             2
# 1          0            24           1  ...           1             2
# 2          0             5           2  ...           1             2
# 3          0             6           2  ...           5             3
# 4          0            15           2  ...           1             2
#
#    GarageQual  GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  SaleType  \
# ...

# %% [markdown]
# ### Combining Label Encoded Categorical Columns and Numeric Columns

# %%
df_numeric = df_combined._get_numeric_data() # need to impute missing value for MasVnrArea
numeric_columns = df_numeric.columns.to_list()

# %%
df_le = pd.DataFrame(np.concatenate([df_numeric,df_categorical_le],axis = 1))
df_le.columns = numeric_columns + categorical_columns
df_le
# Out:
#           Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1.0        60.0         65.0   8450.0          7.0          5.0
# 1        2.0        20.0         80.0   9600.0          6.0          8.0
# 2        3.0        60.0         68.0  11250.0          7.0          5.0
# 3        4.0        70.0         60.0   9550.0          7.0          5.0
# 4        5.0        60.0         84.0  14260.0          8.0          5.0
# ...      ...         ...          ...      ...          ...          ...
# 2914  2915.0       160.0         21.0   1936.0          4.0          7.0
# 2915  2916.0       160.0         21.0   1894.0          4.0          5.0
# 2916  2917.0        20.0        160.0  20000.0          5.0          7.0
# 2917  2918.0        85.0         62.0  10441.0          5.0          5.0
# 2918  2919.0        60.0         74.0   9627.0          7.0          5.0
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageType  \
# ...

# %%
X = df_le.iloc[:1460,:].drop(['Id','SalePrice'],axis =1)
Y = df_le.iloc[:1460,]['SalePrice']
X1 = df_le.iloc[1460:,].drop(['Id','SalePrice'],axis =1) # Original Train dataset

# %% [markdown]
# ### Gradient Boosting Model

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

gbm = GradientBoostingRegressor()
gbm.fit(X,Y)
gbm.score(X,Y)
# Out:
# 0.9655301294733736

# %%
gbm.set_params(verbose=1)
gbm.fit(X,Y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1  5414666697.2413            0.39s
#          2  4670811099.6029            0.34s
#          3  4064945702.8768            0.35s
#          4  3559917680.1599            0.41s
#          5  3127159220.5939            0.42s
#          6  2766554720.6472            0.44s
#          7  2464020257.2934            0.44s
#          8  2206444029.1449            0.44s
#          9  1981905228.2157            0.44s
#         10  1784535935.3719            0.44s
#         20   809356353.9819            0.36s
#         30   510647600.5843            0.29s
#         40   392797074.0168            0.23s
#         50   327028738.4629            0.18s
#         60   292320602.2855            0.15s
#         70   267473609.2618            0.11s
#         80   245723125.3323            0.07s
#         90   233105582.0757            0.03s
#        100   217394185.9758            0.00s
# ...

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
# a train test split of 20% test set
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2,random_state = 42)

# %% [markdown]
# #### Bagging

# %%
gbm.set_params(learning_rate=0.03, n_estimators=800, verbose=1, subsample=0.7, warm_start=False, loss='ls', max_depth=2, max_features=2, min_impurity_decrease=0.01)
# subsample = 0.7: each tree only use random 70% of the whole dataset for bagging
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.03, loss='ls', max_depth=2,
#                           max_features=2, max_leaf_nodes=None,
#                           min_impurity_decrease=0.01, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=800,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=0.7, tol=0.0001,
#                           validation_fraction=0.1, verbose=1, warm_start=False)

# %%
gbm.fit(X_train,Y_train)
print('-'*50)
print("The train set R^2 is %.3f" %(gbm.score(X_train, Y_train)))
print("The test set R^2 is %.3f" %(gbm.score(X_test,Y_test)))
print("The difference between test and train is %.3f" %(gbm.score(X_train, Y_train)-gbm.score(X_test,Y_test)))
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1  5620583792.6783   155435122.2546            0.79s
#          2  6071785387.3925    34917166.9481            0.79s
#          3  5308943884.8331    25577915.0837            0.79s
#          4  5623868520.0724   148237566.0940            0.79s
#          5  5764587470.7242   114079727.2158            0.79s
#          6  4690788829.1582    92458115.4099            0.66s
#          7  5372230434.0731   108141164.8582            0.68s
#          8  5011778247.8027   199588288.9760            0.69s
#          9  4517075235.7430   141024908.3306            0.70s
#         10  5082316763.7644    63101762.3675            0.71s
#         20  4023680246.2571   111426704.3044            0.45s
#         30  3754780595.2126    57926972.1120            0.30s
#         40  3236411890.1709    48761274.7882            0.22s
#         50  2418157472.5853    18408367.9724            0.42s
# ...

# %% [markdown]
# ### Rank the Feature Importance and Select only the top 35 to refit gbm model

# %%
sorted_importance = sorted(zip(X.columns.to_numpy(), gbm.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance_top35 = sorted_importance[:35]
sorted_importance_top35
# Out:
# [('OverallQual', 0.09153377211874582),
#  ('TotalBsmtSF', 0.06044609766749229),
#  ('1stFlrSF', 0.052871149083903606),
#  ('GrLivArea', 0.051896852808706706),
#  ('AdjTotalBsmtSF', 0.05092796057458634),
#  ('KitchenQual', 0.05067866094633549),
#  ('GarageArea', 0.03703572040921474),
#  ('FullBath', 0.028280437989842075),
#  ('BsmtFinSF1', 0.027626466350868847),
#  ('LotArea', 0.02572170035108578),
#  ('2ndFlrSF', 0.02467830512525171),
#  ('TotRmsAbvGrd', 0.023904722237374616),
#  ('AdjTotalBath', 0.022432258970683124),
#  ('ExterQual', 0.022297147554140813),
#  ('MasVnrArea', 0.021930837426076637),
#  ('Fireplaces', 0.01964203410708178),
#  ('GarageType', 0.019194938675162376),
#  ('OpenPorchSF', 0.019171802771061865),
#  ('HouseAge', 0.018680675949228988),
#  ('GarageCars', 0.01735783133876187),
#  ('SaleCondition', 0.017073273306410473),
#  ('Foundation', 0.015058884311299925),
#  ('YearRemodAdd', 0.014768595296068514),
#  ('LotFrontage', 0.014607448201916727),
# ...

# %%
a, b = zip(*sorted_importance_top35) # this splits the list of tuples into two lists
pd.DataFrame({'feature_name':a, 'importance_score':b}).plot.bar(x='feature_name',y='importance_score', legend=None)
plt.title('Feature Importance Plot of 500-Tree GBM')
plt.rcParams['figure.figsize'] = (10,15)

# %%
X_top35 = X.loc[:,list(a)]
X_top35.head(5)
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  AdjTotalBsmtSF  KitchenQual  \
# 0          7.0        856.0     856.0     1710.0           841.0          2.0
# 1          6.0       1262.0    1262.0     1262.0          1233.6          3.0
# 2          7.0        920.0     920.0     1786.0           876.6          2.0
# 3          7.0        756.0     961.0     1717.0           702.0          2.0
# 4          8.0       1145.0    1145.0     2198.0          1096.0          2.0
#
#    GarageArea  FullBath  BsmtFinSF1  LotArea  ...  YearBuilt  HeatingQC  \
# 0       548.0       2.0       706.0   8450.0  ...     2003.0        0.0
# 1       460.0       2.0       978.0   9600.0  ...     1976.0        0.0
# 2       608.0       2.0       486.0  11250.0  ...     2001.0        0.0
# 3       642.0       1.0       216.0   9550.0  ...     1915.0        2.0
# 4       836.0       2.0       655.0  14260.0  ...     2000.0        0.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
# a train test split of 20% test set
X_top35_train, X_top35_test, Y_top35_train, Y_top35_test = train_test_split(X_top35,Y, test_size=0.2,random_state = 42)

# %%
gbm_top35 = GradientBoostingRegressor()
gbm_top35.set_params(learning_rate=0.03, n_estimators=600, verbose=1, subsample=0.7, warm_start=False, loss='ls', max_depth=2, max_features=2, min_impurity_decrease=0.01)
# subsample = 0.7: each tree only use random 70% of the whole dataset for bagging
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.03, loss='ls', max_depth=2,
#                           max_features=2, max_leaf_nodes=None,
#                           min_impurity_decrease=0.01, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=600,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=0.7, tol=0.0001,
#                           validation_fraction=0.1, verbose=1, warm_start=False)

# %%
gbm_top35.fit(X_top35_train,Y_top35_train)
print('-'*50)
print("The train set R^2 is %.3f" %(gbm_top35.score(X_top35_train, Y_top35_train)))
print("The test set R^2 is %.3f" %(gbm_top35.score(X_top35_test,Y_top35_test)))
a = gbm_top35.score(X_top35_train, Y_top35_train)
b = gbm_top35.score(X_top35_test,Y_top35_test)
print("Difference between train and test set R^2 is %.3f" % (a-b))
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1  5467794540.4072   214759343.0750            0.60s
#          2  5823015314.3367   109629414.2069            0.60s
#          3  5550742490.5026    85704901.1313            0.60s
#          4  5015114098.5695   126418692.8195            0.59s
#          5  5246930268.9647   123206694.6624            0.59s
#          6  5489770385.7543   131433857.3926            0.49s
#          7  4909228348.7320   150267119.4381            0.51s
#          8  4984415526.4024    94109977.5441            0.44s
#          9  4754769024.1460   114309455.0350            0.46s
#         10  4173036299.9428   105406873.9901            0.47s
#         20  3573624916.7629    98404574.7939            0.35s
#         30  3082980747.2686    52592356.7062            0.30s
#         40  2380600312.1346    43677477.2028            0.28s
#         50  1836916618.5099    41071215.9056            0.25s
# ...

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV
grid_para_tree = [{
    'n_estimators':np.arange(100,1000,100),
    'learning_rate':np.linspace(0.02,0.05,5),
#     "min_samples_leaf": range(1, 10, 3),
#     'subsample': np.linspace(0.6,0.9,4),
    "min_samples_split": np.linspace(start=2, stop=30, num=7, dtype=int) # not recommend to do a through research, try num =7 first 
}]

gbm_top35.set_params(random_state=108)
grid_search_tree = GridSearchCV(gbm_top35, grid_para_tree, cv=3, n_jobs=6)
# %time grid_search_tree.fit(X_top35_train, Y_top35_train)
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1  5369076098.3476   288125052.6186            0.00s
#          2  5148084213.3823   262783200.0141            0.00s
#          3  4860273835.0211   252804400.8515            0.00s
#          4  4863907656.0413   198480370.0322            0.00s
#          5  4170822483.5435   179750663.0174            0.00s
#          6  4793122861.3826   137054914.3958            0.00s
#          7  4105645157.5182   217268717.5013            0.00s
#          8  4067977350.9486   206056758.2605            0.00s
#          9  4331439627.4617   103614476.0642            0.00s
#         10  3905194275.8029   181120911.2990            0.00s
#         20  2928436072.7073    69269698.6455            0.53s
#         30  2235851912.5285    39657766.7158            0.35s
#         40  1499677345.4730    43711243.3385            0.26s
#         50  1388825449.2106    16614140.7885            0.34s
# ...

# %%
## best parameters
grid_search_tree.best_params_
# Out:
# {'learning_rate': 0.05, 'min_samples_split': 20, 'n_estimators': 900}

# %%
grid_search_tree.best_score_
# Out:
# 0.8534708097804482

# %%
grid_search_tree.score(X_top35_train, Y_top35_train)
# Out:
# 0.9542454561652017

# %%
grid_search_tree.score(X_top35_test, Y_top35_test)
# Out:
# 0.8999833875900783
